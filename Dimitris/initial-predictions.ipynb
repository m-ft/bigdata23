# %% [markdown]
# ### Load the training data

# %%
import os.path as path
import pandas as pd
import numpy as np

def split_features_targets(data):
    x = data.drop(['min_price', 'max_price'], axis = 1)
    y = data[['min_price', 'max_price']]
    return x,y

train_data_path = path.join(path.pardir, 'new_train.csv')
data = pd.read_csv(train_data_path)
X_train, y_train = split_features_targets(data)

X_train.head()
# Out:
#    Unnamed: 0     id                                               name  \
# 0         174  30511  Dell Inspiron 15 5593: 10th Gen Core i5-1035G1...
# 1         231  22136  ASUS ROG Zephyrus GX501 Ultra Slim Gaming Lapt...
# 2         439  26958  Apple MacBook Air MJVE2LL/A 13-inch Laptop 1.6...
# 3         262   8282  ASUS ZenBook UX305CA-EHM1 Laptop (Windows 10, ...
# 4         307  29844  Lenovo 100E Chromebook 2ND Gen Laptop, 11.6" H...
#
#     brand                                base_name  screen_size  pixels_x  \
# 0    Dell                       Dell Inspiron 5593         15.6      1920
# 1    Asus                  Asus ROG Zephyrus GX501         15.6      1920
# 2   Apple                   Apple MacBook Air 2015         13.3      1440
# 3    Asus                Asus ZenBook UX305CA-EHM1         13.3      1920
# 4  Lenovo  Lenovo 100e Chromebook (2nd Generation)         11.6      1366
#
#    pixels_y screen_surface  touchscreen  ...  \
# 0      1080          Matte            0  ...
# 1      1080          Matte            0  ...
# 2       900         Glossy            0  ...
# 3      1080          Matte            0  ...
# 4       768          Matte            0  ...
#
#                                          cpu_details detachable_keyboard  \
# 0  Intel Core i5-1035G1 1.0 GHz (10th gen Ice Lak...                 0.0
# 1  Intel Core i7-8750H 2.2 GHz (8th gen Coffee La...                 0.0
# 2  Intel Core i5-5250U 1.6 GHz (5th gen Broadwell...                 0.0
# 3  Intel Core m3-6Y30 0.9 GHz (6th gen Skylake Du...                 0.0
# 4               MediaTek MT8173C 2.1 GHz (Quad-Core)                 0.0
#
#    discrete_gpu                         gpu         os       os_details ram  \
# 0             0                   Intel UHD    Windows  Windows 10 Home   8
# 1             1     NVIDIA GeForce GTX 1080    Windows   Windows 10 Pro  16
# 2             0               Intel HD 6000      macOS  OS X El Capitan   8
# 3             0                    Intel HD    Windows       Windows 10   8
# 4             0  Imagination PowerVR GX6250  Chrome OS        Chrome OS   4
#
#    ssd  storage  weight
# 0  256      256    4.52
# 1  512      512    5.00
# 2  128      128    2.96
# 3  256      256    2.65
# 4   16       16    2.68
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Feature engineering pipeline

# %% [markdown]
# #### Add `screen_ratio` column

# %%
def add_screen_ratio_column(df):
    df['screen_ratio'] = df['pixels_x'] / df['pixels_y']

df = X_train.copy()
add_screen_ratio_column(df)
df['screen_ratio'].head()
# Out:
# 0    1.777778
# 1    1.777778
# 2    1.600000
# 3    1.777778
# 4    1.778646
# Name: screen_ratio, dtype: float64

# %% [markdown]
# #### Add `clock_speed` column

# %%
def add_clock_speed_column(df):
    df['clock_speed'] = df['cpu_details'].str.extract('(\d+.\d+) GHz')
    df['clock_speed'] = pd.to_numeric(df['clock_speed'])

df = X_train.copy()
add_clock_speed_column(df)
df['clock_speed'].head()
# Out:
# 0    1.0
# 1    2.2
# 2    1.6
# 3    0.9
# 4    2.1
# Name: clock_speed, dtype: float64

# %% [markdown]
# #### Add `cpu_gen` column

# %%
def add_cpu_gen_column(df):
    df['cpu_gen'] = df['cpu_details'].str.extract('(\d+)th gen')
    df['cpu_gen'] = pd.to_numeric(df['cpu_gen'])

df = X_train.copy()
print(df.isnull().values.sum())
add_cpu_gen_column(df)
print(df.isnull().values.sum())
df['cpu_gen'].head()
# Out:
# 25
# 136
# 0    10.0
# 1     8.0
# 2     5.0
# 3     6.0
# 4     NaN
# Name: cpu_gen, dtype: float64

# %% [markdown]
# ####  Add `glossy_screen` column

# %%
def add_glossy_screen_column(df):
    surface = df['screen_surface'].str.lower()
    surface = surface.replace({'' : np.nan, 'glossy' : 1, 'matte' : 0})
    df['glossy_screen'] = surface

df = X_train.copy()
print(df.isnull().values.sum())
add_glossy_screen_column(df)
print(df.isnull().values.sum())
df['glossy_screen'].head()
# Out:
# 25
# 35
# 0    0.0
# 1    0.0
# 2    1.0
# 3    0.0
# 4    0.0
# Name: glossy_screen, dtype: float64

# %% [markdown]
# #### Add `gpu_brand` column

# %%
def add_gpu_brand_column(df):
    df['gpu_brand'] = df['gpu'].str.split().str.get(0)
    df['gpu_brand'] = df['gpu_brand'].replace({'Imagination': 'PowerVR'})

df = X_train.copy()
print(df.isnull().values.sum())
add_gpu_brand_column(df)
print(df.isnull().values.sum())
df['gpu_brand'].head()
# Out:
# 25
# 26
# 0      Intel
# 1     NVIDIA
# 2      Intel
# 3      Intel
# 4    PowerVR
# Name: gpu_brand, dtype: object

# %% [markdown]
# #### Add `hdd` column

# %%
def add_hdd_column(df):
    df['hdd'] = df['storage'] - df['ssd']
    df['hdd'] = pd.to_numeric(df['hdd'])

df = X_train.copy()
add_hdd_column(df)
df['hdd'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: hdd, dtype: int64

# %% [markdown]
# #### Keep only feature columns

# %%
boolean_features = ['glossy_screen', 'touchscreen', 'detachable_keyboard', 'discrete_gpu']
categorical_features = ['brand', 'cpu', 'gpu_brand', 'os_details']
numerical_features = ['screen_size', 'pixels_x', 'screen_ratio', 'clock_speed', 'cpu_gen',
                      'ram', 'ssd', 'hdd', 'weight']
all_features = boolean_features + categorical_features + numerical_features

def keep_only_feature_columns(df):
    return df[all_features].replace({'': np.nan})

# %% [markdown]
# #### Define pipeline as a function

# %%
def engineer_features(df):
    add_screen_ratio_column(df)
    add_clock_speed_column(df)
    add_cpu_gen_column(df)
    add_glossy_screen_column(df)
    add_gpu_brand_column(df)
    add_hdd_column(df)
    return keep_only_feature_columns(df)

# %% [markdown]
# #### Run the pipeline on the training data

# %%
X_train = engineer_features(X_train)
X_train.head()
# Out:
#    glossy_screen  touchscreen  detachable_keyboard  discrete_gpu   brand  \
# 0            0.0            0                  0.0             0    Dell
# 1            0.0            0                  0.0             1    Asus
# 2            1.0            0                  0.0             0   Apple
# 3            0.0            0                  0.0             0    Asus
# 4            0.0            0                  0.0             0  Lenovo
#
#              cpu gpu_brand       os_details  screen_size  pixels_x  \
# 0  Intel Core i5     Intel  Windows 10 Home         15.6      1920
# 1  Intel Core i7    NVIDIA   Windows 10 Pro         15.6      1920
# 2  Intel Core i5     Intel  OS X El Capitan         13.3      1440
# 3  Intel Core m3     Intel       Windows 10         13.3      1920
# 4       MediaTek   PowerVR        Chrome OS         11.6      1366
#
#    screen_ratio  clock_speed  cpu_gen  ram  ssd  hdd  weight
# 0      1.777778          1.0     10.0    8  256    0    4.52
# 1      1.777778          2.2      8.0   16  512    0    5.00
# 2      1.600000          1.6      5.0    8  128    0    2.96
# 3      1.777778          0.9      6.0    8  256    0    2.65
# 4      1.778646          2.1      NaN    4   16    0    2.68

# %% [markdown]
# ### Prepare data for training

# %% [markdown]
# Now that we have defined the features we will use, we need to encode our categorical data using dummy encoding and also deal with missing values in our data. Here, we will need to define our transformations as a scikit-learn pipeline, so that we can fit it to the data while training (and have it learn eg. the mean value that we will use for imputing missing data) and reuse it during testing and for our actual predictions.

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import SimpleImputer, KNNImputer #, IterativeImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# one_hot_encoder = OneHotEncoder(categories = *Not "auto"*, drop = 'first', handle_unknown = 'error')
# To use the above setting, we must first gather all the possible values for our categorical features
one_hot_encoder = OneHotEncoder(categories = 'auto', drop = None, handle_unknown = 'ignore')
most_frequent_imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent', 
                                             add_indicator = True)
# median_imputer = SimpleImputer(missing_values = np.nan, strategy = 'median', 
#                                       add_indicator = True)
# iterative_imputer = IterativeImputer(missing_values = np.nan, add_indicator = True)
knn_imputer = KNNImputer(missing_values = np.nan, add_indicator = True)

numeric_transformer = Pipeline(steps=[
    ('imputer', knn_imputer),
#     ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', most_frequent_imputer),
    ('onehot', one_hot_encoder)
])

boolean_transformer = Pipeline(steps=[
    ('imputer', most_frequent_imputer)
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features),
        ('bool', boolean_transformer, boolean_features)
    ])

# %% [markdown]
# ### Train a classifier

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.multioutput import MultiOutputRegressor
# # Note that random forests etc. don't need this MultiOutputRegressor

# base_clf = LogisticRegression()

# Logistic regression was giving me some trouble with the labels (ValueError: Unknown label type: 'continuous')

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor

# regressor = RandomForestRegressor(n_estimators = 200, criterion = "mae", n_jobs = -1)
base_regressor = GradientBoostingRegressor(n_estimators = 100, criterion = "mae", max_depth = 6)
regressor = MultiOutputRegressor(base_regressor, n_jobs = -1)

clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', regressor)])

clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('imputer',
#                                                                    KNNImputer(add_indicator=True,
#                                                                               copy=True,
#                                                                               metric='nan_euclidean',
#                                                                               missing_values=nan,
#                                                                               n_neighbors=5,
#                                                                               weights='uniform'))],
#                                                            verbose=False),
#                                                   ['screen_size', 'pixel...
#                                                                           max_depth=6,
#                                                                           max_features=None,
#                                                                           max_leaf_nodes=None,
#                                                                           min_impurity_decrease=0.0,
#                                                                           min_impurity_split=None,
#                                                                           min_samples_leaf=1,
#                                                                           min_samples_split=2,
#                                                                           min_weight_fraction_leaf=0.0,
#                                                                           n_estimators=100,
#                                                                           n_iter_no_change=None,
#                                                                           presort='deprecated',
#                                                                           random_state=None,
#                                                                           subsample=1.0,
#                                                                           tol=0.0001,
#                                                                           validation_fraction=0.1,
#                                                                           verbose=0,
#                                                                           warm_start=False),
#                                       n_jobs=-1))],
#          verbose=False)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Load the test data

# %%
test_data_path = path.join(path.pardir, 'new_test.csv')
data = pd.read_csv(test_data_path)
X_test, y_test = split_features_targets(data)

# %% [markdown]
# ### Prepare the test data

# %%
X_test = engineer_features(X_test)
X_test.head()
# Out:
#    glossy_screen  touchscreen  detachable_keyboard  discrete_gpu      brand  \
# 0            1.0            1                  0.0             0  Microsoft
# 1            1.0            1                  0.0             0       Dell
# 2            1.0            1                  1.0             1  Microsoft
# 3            1.0            1                  0.0             1      Razer
# 4            1.0            0                  NaN             0      Apple
#
#              cpu gpu_brand       os_details  screen_size  pixels_x  \
# 0  Intel Core i5     Intel     Windows 10 S         13.5      2256
# 1         AMD A6       AMD  Windows 10 Home         11.6      1366
# 2  Intel Core i7    NVIDIA   Windows 10 Pro         13.5      3000
# 3  Intel Core i7    NVIDIA  Windows 10 Home         13.3      3840
# 4  Intel Core i5     Intel    OS X Yosemite         11.6      1366
#
#    screen_ratio  clock_speed  cpu_gen  ram  ssd  hdd  weight
# 0      1.500000          2.5      7.0    8  256    0    2.76
# 1      1.778646          1.6      7.0    4   32    0    3.41
# 2      1.500000          1.9      8.0   16  512    0    3.62
# 3      1.777778          1.8      8.0   16  512    0    3.04
# 4      1.778646          1.6      5.0    4  128    0    2.38

# %% [markdown]
# ### Evalute the classifier

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test, clf.predict(X_test))
# Out:
# 136.81006088197057

# %% [markdown]
# ## Prediction time!

# %% [markdown]
# If we are satisfied by the results of our evaluation, we are ready to make some predictions on the unknown targets.

# %% [markdown]
# ### Load the prediction data

# %%
prediction_data_path = path.join(path.pardir, 'test.csv')
data = pd.read_csv(prediction_data_path)
data.head()
# Out:
#       id                                               name brand  \
# 0  28807  ASUS ZenBook Flip S Touchscreen Convertible La...  Asus
# 1  22559  Dell Inspiron 15 Intel Core i3-7130U 8GB 1TB H...  Dell
# 2  28647  Asus Vivobook S15 S512 Thin and Light 15.6â€ ...  Asus
# 3  22141  HP 15.6" HD Touchscreen Laptop PC, Intel Core ...    HP
# 4  26116  MSI GS75 Stealth-093 17.3" Razor Thin Bezel Ga...   MSI
#
#                      base_name  screen_size  pixels_x  pixels_y  \
# 0  Asus ZenBook Flip S UX370UA         13.3    1920.0    1080.0
# 1           Dell Inspiron 3567         15.6    1366.0     768.0
# 2         Asus VivoBook S512FA         15.6    1920.0    1080.0
# 3                           HP         15.6    1366.0     768.0
# 4             MSI GS75 Stealth         17.3    1920.0    1080.0
#
#   screen_surface  touchscreen            cpu  \
# 0         Glossy            1  Intel Core i7
# 1          Matte            0  Intel Core i3
# 2          Matte            0  Intel Core i7
# 3         Glossy            1  Intel Core i5
# 4          Matte            0  Intel Core i7
#
#                                          cpu_details  detachable_keyboard  \
# 0  Intel Core i7-8550U 1.8 GHz (8th gen Kaby Lake...                    0
# 1  Intel Core i3-7130U 2.7 GHz (7th gen Kaby Lake...                    0
# 2  Intel Core i7-8565U 1.8 GHz (8th gen Whiskey L...                    0
# 3  Intel Core i5-7200U 2.5 GHz (7th gen Kaby Lake...                    0
# 4  Intel Core i7-8750H 2.2 GHz (8th gen Coffee La...                    0
#
#    discrete_gpu                            gpu       os       os_details  ram  \
# 0             0                  Intel UHD 620  Windows   Windows 10 Pro   16
# 1             0                   Intel HD 620  Windows  Windows 10 Home    8
# 2             0                  Intel UHD 620  Windows  Windows 10 Home    8
# 3             0                   Intel HD 620  Windows  Windows 10 Home    8
# 4             1  NVIDIA GeForce RTX 2080 Max-Q  Windows  Windows 10 Home   32
#
#    ssd  storage  weight
# 0  512      512    2.42
# 1    0     1000    4.95
# 2  256     1256    4.00
# 3  128     2128    4.52
# 4  512      512    4.96

# %% [markdown]
# ### Prepare the prediction data

# %%
X_pred = engineer_features(data)
X_pred.head()
# Out:
#    glossy_screen  touchscreen  detachable_keyboard  discrete_gpu brand  \
# 0            1.0            1                    0             0  Asus
# 1            0.0            0                    0             0  Dell
# 2            0.0            0                    0             0  Asus
# 3            1.0            1                    0             0    HP
# 4            0.0            0                    0             1   MSI
#
#              cpu gpu_brand       os_details  screen_size  pixels_x  \
# 0  Intel Core i7     Intel   Windows 10 Pro         13.3    1920.0
# 1  Intel Core i3     Intel  Windows 10 Home         15.6    1366.0
# 2  Intel Core i7     Intel  Windows 10 Home         15.6    1920.0
# 3  Intel Core i5     Intel  Windows 10 Home         15.6    1366.0
# 4  Intel Core i7    NVIDIA  Windows 10 Home         17.3    1920.0
#
#    screen_ratio  clock_speed  cpu_gen  ram  ssd   hdd  weight
# 0      1.777778          1.8      8.0   16  512     0    2.42
# 1      1.778646          2.7      7.0    8    0  1000    4.95
# 2      1.777778          1.8      8.0    8  256  1000    4.00
# 3      1.778646          2.5      7.0    8  128  2000    4.52
# 4      1.777778          2.2      8.0   32  512     0    4.96

# %% [markdown]
# ### Predict targets

# %%
y_pred = clf.predict(X_pred)
y_pred = pd.DataFrame({'MIN': y_pred[:, 0], 'MAX': y_pred[:, 1]})
y_pred.head()
# Out:
#            MIN          MAX
# 0  1135.878039  1225.820529
# 1   342.919616   358.371210
# 2   814.257965   772.229421
# 3   545.230642   574.769503
# 4  1227.825693  1151.199291

# %% [markdown]
# ### 'Fix" values

# %% [markdown]
# * No min value should be larger than the corresponding max value.
# * We should round the result to the first or second decimal point.

# %%
y_pred['MIN'] = y_pred['MIN'].where(y_pred['MIN'] <= y_pred['MAX'], y_pred['MAX'])
y_pred = y_pred.round(decimals = 2)
y_pred.head()
# Out:
#        MIN      MAX     ID
# 0  1135.88  1225.82  28807
# 1   342.92   358.37  22559
# 2   772.23   772.23  28647
# 3   545.23   574.77  22141
# 4  1151.20  1151.20  26116

# %% [markdown]
# #### Write results to a CSV file

# %%
y_pred['ID'] = data['id']
y_pred = y_pred[['ID', 'MIN', 'MAX']]
y_pred.head()
# Out:
#       ID      MIN      MAX
# 0  28807  1135.88  1225.82
# 1  22559   342.92   358.37
# 2  28647   772.23   772.23
# 3  22141   545.23   574.77
# 4  26116  1151.20  1151.20

# %%
y_pred.to_csv('predictions.csv', index = False)
